# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import pprint 


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 576

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aykhal
# Processing Record 2 of Set 1 | meadow lakes
# Processing Record 3 of Set 1 | west island
# Processing Record 4 of Set 1 | crane
# Processing Record 5 of Set 1 | nemuro
# Processing Record 6 of Set 1 | trujillo
# Processing Record 7 of Set 1 | kegen
# Processing Record 8 of Set 1 | ilulissat
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | puerto natales
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | blackmans bay
# Processing Record 14 of Set 1 | enewetak
# Processing Record 15 of Set 1 | edinburgh of the seven seas
# Processing Record 16 of Set 1 | peniche
# Processing Record 17 of Set 1 | san antonio de pale
# Processing Record 18 of Set 1 | dimbokro
# Processing Record 19 of Set 1 | dzuunharaa
# Processing Record 20 of Set 1 | adamstown
# Processing Record 21 of Set 1 | iskateley
# Processing Record 22 of Set 1 | medicine hat
# Processing Record 23 of Set 1 | mount pearl
# Processing Record 24 of Set 1 | bilibino
# Processing Record 25 of Set 1 | nuriootpa
# Processing Record 26 of Set 1 | asubulaq
# Processing Record 27 of Set 1 | lerwick
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | inarajan village
# Processing Record 30 of Set 1 | port douglas
# Processing Record 31 of Set 1 | minas de marcona
# Processing Record 32 of Set 1 | ust-nera
# Processing Record 33 of Set 1 | labytnangi
# Processing Record 34 of Set 1 | amble
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | saksaul'skiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | oltinko'l
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | papatowai
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | kupang
# Processing Record 43 of Set 1 | tsiombe
# Processing Record 44 of Set 1 | baikonur
# Processing Record 45 of Set 1 | hawaiian paradise park
# Processing Record 46 of Set 1 | waitangi
# Processing Record 47 of Set 1 | frankenmuth
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | yarmouth
# Processing Record 50 of Set 1 | invercargill
# Processing Record 0 of Set 2 | uturoa
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | bikin
# Processing Record 3 of Set 2 | acarau
# Processing Record 4 of Set 2 | petrozavodsk
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | anadyr
# Processing Record 7 of Set 2 | anantapur
# Processing Record 8 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 2 | wailua homesteads
# Processing Record 10 of Set 2 | olyokminsk
# Processing Record 11 of Set 2 | ponta delgada
# Processing Record 12 of Set 2 | kulia village
# City not found. Skipping...
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | kourou
# Processing Record 15 of Set 2 | revda
# Processing Record 16 of Set 2 | hammerfest
# Processing Record 17 of Set 2 | suva
# Processing Record 18 of Set 2 | viedma
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | port saint john's
# Processing Record 22 of Set 2 | oruro
# Processing Record 23 of Set 2 | zemio
# Processing Record 24 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 2 | ouesso
# Processing Record 26 of Set 2 | labrador city
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | saudarkrokur
# Processing Record 29 of Set 2 | fisterra
# Processing Record 30 of Set 2 | joao camara
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | vorgashor
# Processing Record 34 of Set 2 | manokwari
# Processing Record 35 of Set 2 | whitehorse
# Processing Record 36 of Set 2 | chonchi
# Processing Record 37 of Set 2 | general jose de san martin
# Processing Record 38 of Set 2 | ushuaia
# Processing Record 39 of Set 2 | kailua-kona
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | asekeyevo
# Processing Record 42 of Set 2 | colonia
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | maragogi
# Processing Record 45 of Set 2 | margaret river
# Processing Record 46 of Set 2 | itaituba
# Processing Record 47 of Set 2 | opuwo
# Processing Record 48 of Set 2 | kerikeri
# Processing Record 49 of Set 2 | margate
# Processing Record 0 of Set 3 | jamestown
# Processing Record 1 of Set 3 | olinda
# Processing Record 2 of Set 3 | tocopilla
# Processing Record 3 of Set 3 | ha'il
# Processing Record 4 of Set 3 | tamanrasset
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | ishpeming
# Processing Record 7 of Set 3 | peace river
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | ormond-by-the-sea
# Processing Record 10 of Set 3 | carloforte
# Processing Record 11 of Set 3 | envira
# Processing Record 12 of Set 3 | sorong
# Processing Record 13 of Set 3 | thunder bay
# Processing Record 14 of Set 3 | chibougamau
# Processing Record 15 of Set 3 | tazovsky
# Processing Record 16 of Set 3 | pandan
# Processing Record 17 of Set 3 | dauphin
# Processing Record 18 of Set 3 | nantucket
# Processing Record 19 of Set 3 | punta arenas
# Processing Record 20 of Set 3 | bugene
# Processing Record 21 of Set 3 | mwinilunga
# Processing Record 22 of Set 3 | luban
# Processing Record 23 of Set 3 | polyarnyy
# Processing Record 24 of Set 3 | waimea
# Processing Record 25 of Set 3 | anse a galets
# Processing Record 26 of Set 3 | stanley
# Processing Record 27 of Set 3 | kattivakkam
# Processing Record 28 of Set 3 | lyantor
# Processing Record 29 of Set 3 | al jawf
# Processing Record 30 of Set 3 | severo-yeniseyskiy
# Processing Record 31 of Set 3 | aasiaat
# Processing Record 32 of Set 3 | chico
# Processing Record 33 of Set 3 | galesong
# Processing Record 34 of Set 3 | olonkinbyen
# Processing Record 35 of Set 3 | gidrotorf
# Processing Record 36 of Set 3 | linden
# Processing Record 37 of Set 3 | imbituba
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | norrtalje
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | dahab
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | fort st. john
# Processing Record 44 of Set 3 | fortuna
# Processing Record 45 of Set 3 | utrik
# Processing Record 46 of Set 3 | taoudenni
# Processing Record 47 of Set 3 | sisimiut
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | vilyuchinsk
# Processing Record 0 of Set 4 | klyuchi
# Processing Record 1 of Set 4 | beylikova
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | altai
# Processing Record 4 of Set 4 | new plymouth
# Processing Record 5 of Set 4 | petrolina
# Processing Record 6 of Set 4 | port mathurin
# Processing Record 7 of Set 4 | brookings
# Processing Record 8 of Set 4 | malindi
# Processing Record 9 of Set 4 | college
# Processing Record 10 of Set 4 | kingston
# Processing Record 11 of Set 4 | ragana
# Processing Record 12 of Set 4 | zhosaly
# Processing Record 13 of Set 4 | xiva
# Processing Record 14 of Set 4 | okhotsk
# Processing Record 15 of Set 4 | vila do maio
# Processing Record 16 of Set 4 | uusikaupunki
# Processing Record 17 of Set 4 | porto novo
# Processing Record 18 of Set 4 | udachny
# Processing Record 19 of Set 4 | biltine
# Processing Record 20 of Set 4 | sydney
# Processing Record 21 of Set 4 | port-vila
# Processing Record 22 of Set 4 | kilju
# Processing Record 23 of Set 4 | selfoss
# Processing Record 24 of Set 4 | sao vicente
# Processing Record 25 of Set 4 | neyshabur
# Processing Record 26 of Set 4 | kavaratti
# Processing Record 27 of Set 4 | badger
# Processing Record 28 of Set 4 | ulladulla
# Processing Record 29 of Set 4 | kumru
# Processing Record 30 of Set 4 | coquimbo
# Processing Record 31 of Set 4 | grand falls-windsor
# Processing Record 32 of Set 4 | yilan
# Processing Record 33 of Set 4 | debre mark'os
# Processing Record 34 of Set 4 | allende
# Processing Record 35 of Set 4 | weno
# Processing Record 36 of Set 4 | nar'yan-mar
# Processing Record 37 of Set 4 | afaahiti
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | port alfred
# Processing Record 40 of Set 4 | banff
# Processing Record 41 of Set 4 | eyl
# Processing Record 42 of Set 4 | szombathely
# Processing Record 43 of Set 4 | talnakh
# Processing Record 44 of Set 4 | cockburn town
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | arteche
# Processing Record 47 of Set 4 | hobyo
# Processing Record 48 of Set 4 | ingeniero jacobacci
# Processing Record 49 of Set 4 | brak
# Processing Record 0 of Set 5 | kapuskasing
# Processing Record 1 of Set 5 | sogndal
# Processing Record 2 of Set 5 | kletnya
# Processing Record 3 of Set 5 | zaozersk
# Processing Record 4 of Set 5 | coahuayana de hidalgo
# Processing Record 5 of Set 5 | tamiahua
# Processing Record 6 of Set 5 | karwar
# Processing Record 7 of Set 5 | kolonia town
# Processing Record 8 of Set 5 | gargalianoi
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | khark
# Processing Record 11 of Set 5 | ancud
# Processing Record 12 of Set 5 | aral
# Processing Record 13 of Set 5 | keflavik
# Processing Record 14 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 15 of Set 5 | dunedin
# Processing Record 16 of Set 5 | dudinka
# Processing Record 17 of Set 5 | san luis
# Processing Record 18 of Set 5 | hadibu
# Processing Record 19 of Set 5 | ngetkib
# Processing Record 20 of Set 5 | tura
# Processing Record 21 of Set 5 | ketchikan
# Processing Record 22 of Set 5 | nampa
# Processing Record 23 of Set 5 | sosnovka
# Processing Record 24 of Set 5 | hamilton
# Processing Record 25 of Set 5 | yuzhno-kurilsk
# Processing Record 26 of Set 5 | roma
# Processing Record 27 of Set 5 | mount isa
# Processing Record 28 of Set 5 | constantia
# Processing Record 29 of Set 5 | kununurra
# Processing Record 30 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 31 of Set 5 | cannonvale
# Processing Record 32 of Set 5 | mariehamn
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | havran
# Processing Record 35 of Set 5 | macau
# Processing Record 36 of Set 5 | atafu village
# Processing Record 37 of Set 5 | de aar
# Processing Record 38 of Set 5 | isangel
# Processing Record 39 of Set 5 | lihue
# Processing Record 40 of Set 5 | kayangel
# Processing Record 41 of Set 5 | igarka
# Processing Record 42 of Set 5 | portland
# Processing Record 43 of Set 5 | ishiki
# Processing Record 44 of Set 5 | awjilah
# Processing Record 45 of Set 5 | thames
# Processing Record 46 of Set 5 | tyre
# Processing Record 47 of Set 5 | vadso
# Processing Record 48 of Set 5 | verkhnevilyuysk
# Processing Record 49 of Set 5 | center
# Processing Record 0 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 1 of Set 6 | cleveland
# Processing Record 2 of Set 6 | vernon
# Processing Record 3 of Set 6 | corner brook
# Processing Record 4 of Set 6 | valdivia
# Processing Record 5 of Set 6 | santaquin
# Processing Record 6 of Set 6 | mount gambier
# Processing Record 7 of Set 6 | ghadamis
# Processing Record 8 of Set 6 | nicolet
# Processing Record 9 of Set 6 | meulaboh
# Processing Record 10 of Set 6 | rukban
# City not found. Skipping...
# Processing Record 11 of Set 6 | santa cruz
# Processing Record 12 of Set 6 | fale old settlement
# Processing Record 13 of Set 6 | taco pozo
# Processing Record 14 of Set 6 | stornoway
# Processing Record 15 of Set 6 | qaqortoq
# Processing Record 16 of Set 6 | villa gesell
# Processing Record 17 of Set 6 | east foothills
# Processing Record 18 of Set 6 | kemijarvi
# Processing Record 19 of Set 6 | san rafael
# Processing Record 20 of Set 6 | gadzhiyevo
# Processing Record 21 of Set 6 | calimanesti
# Processing Record 22 of Set 6 | bata
# Processing Record 23 of Set 6 | newman
# Processing Record 24 of Set 6 | machico
# Processing Record 25 of Set 6 | alofi
# Processing Record 26 of Set 6 | maine soroa
# Processing Record 27 of Set 6 | tolanaro
# Processing Record 28 of Set 6 | kirchberg in tirol
# Processing Record 29 of Set 6 | lekki
# City not found. Skipping...
# Processing Record 30 of Set 6 | deniliquin
# Processing Record 31 of Set 6 | khandyga
# Processing Record 32 of Set 6 | st. john's
# Processing Record 33 of Set 6 | kuraymah
# Processing Record 34 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 35 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 36 of Set 6 | martapura
# Processing Record 37 of Set 6 | el granada
# Processing Record 38 of Set 6 | polewali
# Processing Record 39 of Set 6 | antofagasta
# Processing Record 40 of Set 6 | canico
# Processing Record 41 of Set 6 | east london
# Processing Record 42 of Set 6 | balabac
# Processing Record 43 of Set 6 | kindia
# Processing Record 44 of Set 6 | xiuyan
# Processing Record 45 of Set 6 | cidreira
# Processing Record 46 of Set 6 | khenchela
# Processing Record 47 of Set 6 | el eulma
# Processing Record 48 of Set 6 | remire-montjoly
# Processing Record 49 of Set 6 | hotan
# Processing Record 0 of Set 7 | riachao
# Processing Record 1 of Set 7 | conception bay south
# Processing Record 2 of Set 7 | codrington
# Processing Record 3 of Set 7 | tidjikja
# Processing Record 4 of Set 7 | rongelap
# Processing Record 5 of Set 7 | port hedland
# Processing Record 6 of Set 7 | cerkezkoy
# Processing Record 7 of Set 7 | kisangani
# Processing Record 8 of Set 7 | springbok
# Processing Record 9 of Set 7 | booue
# Processing Record 10 of Set 7 | boa vista
# Processing Record 11 of Set 7 | mili
# Processing Record 12 of Set 7 | kristiansund
# Processing Record 13 of Set 7 | ahau
# City not found. Skipping...
# Processing Record 14 of Set 7 | kapa'a
# Processing Record 15 of Set 7 | ararangua
# Processing Record 16 of Set 7 | ndele
# Processing Record 17 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 7 | bayganin
# Processing Record 19 of Set 7 | kavieng
# Processing Record 20 of Set 7 | makary
# Processing Record 21 of Set 7 | castillos
# Processing Record 22 of Set 7 | sanctuary point
# Processing Record 23 of Set 7 | cabo san lucas
# Processing Record 24 of Set 7 | maiwut
# City not found. Skipping...
# Processing Record 25 of Set 7 | bentiu
# Processing Record 26 of Set 7 | extrema
# Processing Record 27 of Set 7 | sarkand
# Processing Record 28 of Set 7 | vilyuysk
# Processing Record 29 of Set 7 | akureyri
# Processing Record 30 of Set 7 | baruun-urt
# Processing Record 31 of Set 7 | vila velha
# Processing Record 32 of Set 7 | pathein
# Processing Record 33 of Set 7 | rabaul
# Processing Record 34 of Set 7 | kpandae
# Processing Record 35 of Set 7 | camarinas
# Processing Record 36 of Set 7 | itamarandiba
# Processing Record 37 of Set 7 | sinabang
# Processing Record 38 of Set 7 | uliastay
# Processing Record 39 of Set 7 | sijunjung
# Processing Record 40 of Set 7 | laguna
# Processing Record 41 of Set 7 | jacmel
# Processing Record 42 of Set 7 | flekkefjord
# Processing Record 43 of Set 7 | masterton
# Processing Record 44 of Set 7 | strezhevoy
# Processing Record 45 of Set 7 | haiku-pauwela
# Processing Record 46 of Set 7 | nova vicosa
# Processing Record 47 of Set 7 | nyurba
# Processing Record 48 of Set 7 | mirny
# Processing Record 49 of Set 7 | safford
# Processing Record 0 of Set 8 | kodinsk
# Processing Record 1 of Set 8 | makokou
# Processing Record 2 of Set 8 | urzhar
# Processing Record 3 of Set 8 | veymandoo
# City not found. Skipping...
# Processing Record 4 of Set 8 | seogwipo
# City not found. Skipping...
# Processing Record 5 of Set 8 | murygino
# Processing Record 6 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 7 of Set 8 | stephenville
# Processing Record 8 of Set 8 | shetpe
# Processing Record 9 of Set 8 | klaksvik
# Processing Record 10 of Set 8 | vallenar
# Processing Record 11 of Set 8 | pisco
# Processing Record 12 of Set 8 | nabire
# Processing Record 13 of Set 8 | sibu
# Processing Record 14 of Set 8 | qusmuryn
# Processing Record 15 of Set 8 | sumberpucung
# Processing Record 16 of Set 8 | butjadingen
# Processing Record 17 of Set 8 | ostashkov
# Processing Record 18 of Set 8 | puerto santa
# Processing Record 19 of Set 8 | itoman
# Processing Record 20 of Set 8 | al ghayzah
# Processing Record 21 of Set 8 | osakarovka
# Processing Record 22 of Set 8 | susuman
# Processing Record 23 of Set 8 | general conesa
# Processing Record 24 of Set 8 | al bardiyah
# Processing Record 25 of Set 8 | mlimba
# Processing Record 26 of Set 8 | inhambane
# Processing Record 27 of Set 8 | hakui
# Processing Record 28 of Set 8 | pamandzi
# Processing Record 29 of Set 8 | salekhard
# Processing Record 30 of Set 8 | kittila
# Processing Record 31 of Set 8 | boysun
# Processing Record 32 of Set 8 | bamboo flat
# Processing Record 33 of Set 8 | rio grande
# Processing Record 34 of Set 8 | sechura
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | abashiri
# Processing Record 37 of Set 8 | hami
# Processing Record 38 of Set 8 | hampton bays
# Processing Record 39 of Set 8 | wenzhou
# Processing Record 40 of Set 8 | crossett
# Processing Record 41 of Set 8 | gwadar
# Processing Record 42 of Set 8 | sucua
# Processing Record 43 of Set 8 | pembroke
# Processing Record 44 of Set 8 | smithers
# Processing Record 45 of Set 8 | shahrud
# Processing Record 46 of Set 8 | arinos
# Processing Record 47 of Set 8 | chegdomyn
# Processing Record 48 of Set 8 | turabah
# Processing Record 49 of Set 8 | north bend
# Processing Record 0 of Set 9 | ostuni
# Processing Record 1 of Set 9 | egilsstadir
# Processing Record 2 of Set 9 | carnarvon
# Processing Record 3 of Set 9 | argo
# Processing Record 4 of Set 9 | smara
# Processing Record 5 of Set 9 | kargasok
# Processing Record 6 of Set 9 | guaraniacu
# Processing Record 7 of Set 9 | tevragh zeina
# City not found. Skipping...
# Processing Record 8 of Set 9 | wuwei
# Processing Record 9 of Set 9 | dobrich
# Processing Record 10 of Set 9 | burela de cabo
# Processing Record 11 of Set 9 | idri
# Processing Record 12 of Set 9 | pustoshka
# Processing Record 13 of Set 9 | morehead city
# Processing Record 14 of Set 9 | nova sintra
# Processing Record 15 of Set 9 | ust'-kut
# Processing Record 16 of Set 9 | kone
# Processing Record 17 of Set 9 | katabu
# Processing Record 18 of Set 9 | inongo
# Processing Record 19 of Set 9 | kanniyakumari
# Processing Record 20 of Set 9 | outjo
# Processing Record 21 of Set 9 | dunbar
# Processing Record 22 of Set 9 | sirte
# Processing Record 23 of Set 9 | nebbi
# Processing Record 24 of Set 9 | sumenep
# Processing Record 25 of Set 9 | kani keli
# Processing Record 26 of Set 9 | yangjiang
# Processing Record 27 of Set 9 | demirci
# Processing Record 28 of Set 9 | maintirano
# Processing Record 29 of Set 9 | lagunas
# Processing Record 30 of Set 9 | arenapolis
# Processing Record 31 of Set 9 | salalah
# Processing Record 32 of Set 9 | nguigmi
# Processing Record 33 of Set 9 | progreso
# Processing Record 34 of Set 9 | likiep
# Processing Record 35 of Set 9 | xining
# Processing Record 36 of Set 9 | mana
# Processing Record 37 of Set 9 | tukrah
# Processing Record 38 of Set 9 | baynjiwayn
# Processing Record 39 of Set 9 | lakheri
# Processing Record 40 of Set 9 | clodomira
# Processing Record 41 of Set 9 | bandarbeyla
# Processing Record 42 of Set 9 | mo i rana
# Processing Record 43 of Set 9 | kathmandu
# Processing Record 44 of Set 9 | kyzyl-mazhalyk
# Processing Record 45 of Set 9 | pechora
# Processing Record 46 of Set 9 | domna
# Processing Record 47 of Set 9 | messaad
# Processing Record 48 of Set 9 | tekkali
# Processing Record 49 of Set 9 | sangsong-ni
# Processing Record 0 of Set 10 | sakiai
# Processing Record 1 of Set 10 | tarnogskiy gorodok
# Processing Record 2 of Set 10 | port blair
# Processing Record 3 of Set 10 | barddhaman
# Processing Record 4 of Set 10 | kaset sombun
# Processing Record 5 of Set 10 | straldzha
# Processing Record 6 of Set 10 | isafjordur
# Processing Record 7 of Set 10 | quellon
# Processing Record 8 of Set 10 | kampli
# Processing Record 9 of Set 10 | escanaba
# Processing Record 10 of Set 10 | brigantine
# Processing Record 11 of Set 10 | las navas del marques
# Processing Record 12 of Set 10 | island harbour
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | balikpapan
# Processing Record 15 of Set 10 | buckie
# Processing Record 16 of Set 10 | dampit
# Processing Record 17 of Set 10 | quepos
# Processing Record 18 of Set 10 | new norfolk
# Processing Record 19 of Set 10 | singaraja
# Processing Record 20 of Set 10 | watertown
# Processing Record 21 of Set 10 | howrah
# Processing Record 22 of Set 10 | muroto-misakicho
# Processing Record 23 of Set 10 | moorhead
# Processing Record 24 of Set 10 | kamiiso
# Processing Record 25 of Set 10 | bodo
# Processing Record 26 of Set 10 | fort bragg
# Processing Record 27 of Set 10 | craig
# Processing Record 28 of Set 10 | jayapura
# Processing Record 29 of Set 10 | antsiranana
# Processing Record 30 of Set 10 | zgornje jezersko
# Processing Record 31 of Set 10 | saipan
# Processing Record 32 of Set 10 | xilin hot
# Processing Record 33 of Set 10 | nadi
# Processing Record 34 of Set 10 | palikir - national government center
# Processing Record 35 of Set 10 | sao felix do xingu
# Processing Record 36 of Set 10 | kuta
# Processing Record 37 of Set 10 | badiyah
# Processing Record 38 of Set 10 | necochea
# Processing Record 39 of Set 10 | clinton
# Processing Record 40 of Set 10 | katsuura
# Processing Record 41 of Set 10 | anaconda
# Processing Record 42 of Set 10 | al burayqah
# Processing Record 43 of Set 10 | huarmey
# Processing Record 44 of Set 10 | phek
# Processing Record 45 of Set 10 | ha giang
# Processing Record 46 of Set 10 | shimoda
# Processing Record 47 of Set 10 | muisne
# Processing Record 48 of Set 10 | namibe
# Processing Record 49 of Set 10 | saint-pierre
# Processing Record 0 of Set 11 | howard springs
# Processing Record 1 of Set 11 | la passe
# Processing Record 2 of Set 11 | madison
# Processing Record 3 of Set 11 | geraldton
# Processing Record 4 of Set 11 | kloulklubed
# Processing Record 5 of Set 11 | petauke
# Processing Record 6 of Set 11 | badulla
# Processing Record 7 of Set 11 | queensbury
# Processing Record 8 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 11 | wuchang
# Processing Record 10 of Set 11 | braganca
# Processing Record 11 of Set 11 | bandon
# Processing Record 12 of Set 11 | manzanares
# Processing Record 13 of Set 11 | sonoita
# Processing Record 14 of Set 11 | tazacorte
# Processing Record 15 of Set 11 | sola
# Processing Record 16 of Set 11 | palembang
# Processing Record 17 of Set 11 | bayanhongor
# Processing Record 18 of Set 11 | coihueco
# Processing Record 19 of Set 11 | taraz
# Processing Record 20 of Set 11 | san patricio
# Processing Record 21 of Set 11 | zarghun shahr
# Processing Record 22 of Set 11 | berehove
# Processing Record 23 of Set 11 | sarmiento
# Processing Record 24 of Set 11 | filadelfia
# Processing Record 25 of Set 11 | al qubbah
# Processing Record 26 of Set 11 | belize city
# Processing Record 27 of Set 11 | pacasmayo
# Processing Record 28 of Set 11 | dzilam gonzalez
# Processing Record 29 of Set 11 | ganshui
# Processing Record 30 of Set 11 | daltonganj
# Processing Record 31 of Set 11 | dayton
# Processing Record 32 of Set 11 | agua prieta
# Processing Record 33 of Set 11 | praia da vitoria
# Processing Record 34 of Set 11 | barra de santo antonio
# Processing Record 35 of Set 11 | magadan
# Processing Record 36 of Set 11 | vidyayevo
# Processing Record 37 of Set 11 | locharbriggs
# Processing Record 38 of Set 11 | kilindoni
# Processing Record 39 of Set 11 | aksu
# Processing Record 40 of Set 11 | montecristi
# Processing Record 41 of Set 11 | manistee
# Processing Record 42 of Set 11 | agat village
# Processing Record 43 of Set 11 | novo aripuana
# Processing Record 44 of Set 11 | yashan
# Processing Record 45 of Set 11 | taltal
# Processing Record 46 of Set 11 | ust'-ilimsk
# Processing Record 47 of Set 11 | wakkanai
# Processing Record 48 of Set 11 | sabinov
# Processing Record 49 of Set 11 | el calafate
# Processing Record 0 of Set 12 | dryden
# Processing Record 1 of Set 12 | kargopol'
# Processing Record 2 of Set 12 | papayal
# Processing Record 3 of Set 12 | longboat key
# Processing Record 4 of Set 12 | dakhla
# Processing Record 5 of Set 12 | bismarck
# Processing Record 6 of Set 12 | paracuru
# Processing Record 7 of Set 12 | kaiapoi
# Processing Record 8 of Set 12 | tromso
# Processing Record 9 of Set 12 | luanda
# Processing Record 10 of Set 12 | villa angela
# Processing Record 11 of Set 12 | kasongo-lunda
# Processing Record 12 of Set 12 | mejit
# Processing Record 13 of Set 12 | seven pagodas
# Processing Record 14 of Set 12 | ta`u
# Processing Record 15 of Set 12 | elmendorf air force base
# City not found. Skipping...
# Processing Record 16 of Set 12 | kish
# Processing Record 17 of Set 12 | kuanda
# Processing Record 18 of Set 12 | burao
# Processing Record 19 of Set 12 | winejok
# City not found. Skipping...
# Processing Record 20 of Set 12 | kudahuvadhoo
# Processing Record 21 of Set 12 | mezhdurechensk
# Processing Record 22 of Set 12 | tarko-sale
# Processing Record 23 of Set 12 | makoua
# Processing Record 24 of Set 12 | bambari
# Processing Record 25 of Set 12 | hoxtolgay
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          555
# Lat           555
# Lng           555
# Max Temp      555
# Humidity      555
# Cloudiness    555
# Wind Speed    555
# Country       555
# Date          555
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        aykhal  66.0000  111.5000    -21.43       100         100
# 1  meadow lakes  61.6247 -149.6011      0.35        85           0
# 2   west island -12.1568   96.8225     26.99        89         100
# 3         crane  31.3974 -102.3501     15.11        36           4
# 4        nemuro  43.3236  145.5750     -7.71        78          98
#
#    Wind Speed Country        Date
# 0        2.36      RU  1707169269
# 1        0.00      US  1707169270
# 2        3.09      CC  1707169270
# 3        2.11      US  1707169270
# 4        5.79      JP  1707169270

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              aykhal  66.0000  111.5000    -21.43       100         100
# 1        meadow lakes  61.6247 -149.6011      0.35        85           0
# 2         west island -12.1568   96.8225     26.99        89         100
# 3               crane  31.3974 -102.3501     15.11        36           4
# 4              nemuro  43.3236  145.5750     -7.71        78          98
#
#          Wind Speed Country        Date
# City_ID
# 0              2.36      RU  1707169269
# 1              0.00      US  1707169270
# 2              3.09      CC  1707169270
# 3              2.11      US  1707169270
# 4              5.79      JP  1707169270

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
fig, ax = plt.subplots(figsize=(8, 8))
plt.scatter(x_values,y_values,s=80, marker='o', c='#216F86',alpha=.75, edgecolors='black')
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Temperature (C)')
plt.title('City Max Latitude vs. Temperature (2022-10-18)')
plt.grid()
plt.show()
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
fig, ax = plt.subplots(figsize=(8, 8))
plt.scatter(x_values,y_values,s=80, marker='o', c='#216F86',alpha=.75, edgecolors='black')
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Max Latitude vs. Humidity (2022-10-18)')
plt.grid()
plt.show()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
fig, ax = plt.subplots(figsize=(8, 8))
plt.scatter(x_values,y_values,s=80, marker='o', c='#216F86',alpha=.75, edgecolors='black')

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Max Latitude vs. Cloudiness (2022-10-18)')
plt.grid()
plt.show()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
fig, ax = plt.subplots(figsize=(8, 8))
plt.scatter(x_values,y_values,s=80, marker='o', c='#216F86',alpha=.75, edgecolors='black')
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Max Latitude vs. Wind Speed (2022-10-18)')
plt.grid()
plt.show()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df=city_data_df[(city_data_df["Lat"]>= 0)]
# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              aykhal  66.0000  111.5000    -21.43       100         100
# 1        meadow lakes  61.6247 -149.6011      0.35        85           0
# 3               crane  31.3974 -102.3501     15.11        36           4
# 4              nemuro  43.3236  145.5750     -7.71        78          98
# 6               kegen  43.0197   79.2203    -13.83        77         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.36      RU  1707169269
# 1              0.00      US  1707169270
# 3              2.11      US  1707169270
# 4              5.79      JP  1707169270
# 6              2.92      KZ  1707169271

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df=city_data_df[(city_data_df["Lat"]< 0)]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2              west island -12.1568  96.8225     26.99        89         100
# 5                 trujillo  -8.1160 -79.0300     25.98        69          40
# 8                grytviken -54.2811 -36.5092      6.99        74          90
# 9           puerto natales -51.7236 -72.4875     15.25        38          20
# 11       port-aux-francais -49.3500  70.2167      5.94        82          99
#
#          Wind Speed Country        Date
# City_ID
# 2              3.09      CC  1707169270
# 5              4.63      PE  1707169144
# 8              5.79      GS  1707169271
# 9             15.43      CL  1707169271
# 11            12.42      TF  1707169272

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regressval = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
 
fig, ax = plt.subplots(figsize=(8, 6))
plt.scatter(x_values,y_values)
 
plt.plot(x_values,regressval,"r-")
plt.annotate(line_equation,(10,-30),fontsize=15,color="red")
 
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

print(f"r-value: {rvalue**2}")
 
plt.show()
# Out:
# r-value: 0.7317614067320556

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regressval = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
 
fig, ax = plt.subplots(figsize=(8, 6))
plt.scatter(x_values,y_values)
 
plt.plot(x_values,regressval,"r-")
plt.annotate(line_equation,(-20,10),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Max Temp')

print(f"r-value: {rvalue**2}")
 
plt.show()
# Out:
# r-value: 0.19518184059045252

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regressval = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
 
fig, ax = plt.subplots(figsize=(8,6))
plt.scatter(x_values,y_values)
 
plt.plot(x_values,regressval,"r-")
plt.annotate(line_equation,(50,20),fontsize=15,color="red")
 
plt.xlabel('Latitude')
plt.ylabel('Humidity')

print(f"r-value: {rvalue**2}")
 
plt.show()
# Out:
# r-value: 0.16306602846394974

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regressval = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
 
fig, ax = plt.subplots(figsize=(8, 6))
plt.scatter(x_values,y_values)
 
plt.plot(x_values,regressval,"r-")
plt.annotate(line_equation,(-20,20),fontsize=15,color="red")
 
plt.xlabel('Latitude')
plt.ylabel('Humidity')

print(f"R-value: {rvalue**2}")

plt.show()
# Out:
# R-value: 0.24030441338625

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regressval = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
 
fig, ax = plt.subplots(figsize=(8, 6))
plt.scatter(x_values,y_values)
 
plt.plot(x_values,regressval,"r-")
plt.annotate(line_equation,(50,10),fontsize=15,color="red")
 
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

print(f"R-value: {rvalue**2}")
 
plt.show()
# Out:
# R-value: 0.05957011749377622

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regressval = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
 
fig, ax = plt.subplots(figsize=(8,6))
plt.scatter(x_values,y_values)
 
plt.plot(x_values,regressval,"r-")
plt.annotate(line_equation,(-30,35),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Coudiness')

print(f"R-value: {rvalue**2}")
 
plt.show()
# Out:
# R-value: 0.03590337735191212

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regressval = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
 
fig, ax = plt.subplots(figsize=(8, 6))
plt.scatter(x_values,y_values)
 
plt.plot(x_values,regressval,"r-")
plt.annotate(line_equation,(10,14),fontsize=15,color="red")
 
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

print(f"R-value: {rvalue**2}")

plt.show()
# Out:
# R-value: 0.020781778542924186

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regressval = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
 
fig, ax = plt.subplots(figsize=(8,6))
plt.scatter(x_values,y_values)
 
plt.plot(x_values,regressval,"r-")
plt.annotate(line_equation,(-50,12),fontsize=15,color="red")
 
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

print(f"R-value: {rvalue**2}")
 
plt.show()
# Out:
# R-value: 0.12177886013587444

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
